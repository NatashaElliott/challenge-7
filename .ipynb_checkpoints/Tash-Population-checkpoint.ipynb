# %%
# Import dependencies
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
# Data files
census_2018 = Path("Data/censusdata2018.csv")
census_2019 = Path("Data/censusdata2019.csv")
ambulance_2018 = Path("Data/ambulance2018.csv")
ambulance_2019 = Path("Data/ambulance2019.csv")

# %%
# Convert to dataframes
census_data_2018 = pd.read_csv(census_2018)
ambulance_data_2018 = pd.read_csv(ambulance_2018)
census_data_2019 = pd.read_csv(census_2019)
ambulance_data_2019 = pd.read_csv(ambulance_2019)

# %%
# Clean data to filter and remove all states except Victoria for 2018
census_data_2018_vic = census_data_2018[census_data_2018["S/T name"] == "Victoria"]
# Remove all unnecessary columns to find total persons per UCL for 2018
census_data_2018_vic = census_data_2018_vic.iloc[:,[9,28]]
# Clean data to filter and remove all states except Victoria for 2019
census_data_2019_vic = census_data_2019[census_data_2019["S/T name"] == "Victoria"]
# Remove all unnecessary columns to find total persons per UCL for 2019
census_data_2019_vic = census_data_2019_vic.iloc[:,[9,28]]

# %%
# Display the 2018 census data
census_data_2018_vic.head()
# Out:
#              SA2 name  Total Persons
# 579         Alfredton        13291.0
# 580          Ballarat        12175.0
# 581  Ballarat - North        24147.0
# 582  Ballarat - South        25389.0
# 583         Buninyong         7583.0

# %%
# Display the 2019 census data
census_data_2019_vic.head()
# Out:
#              SA2 name  Total Persons
# 579         Alfredton        14069.0
# 580          Ballarat        12225.0
# 581  Ballarat - North        24457.0
# 582  Ballarat - South        25594.0
# 583         Buninyong         7712.0

# %%
# Merge 2018 dataframes
merged_df_2018 = pd.merge(ambulance_data_2018, census_data_2018_vic, left_on="UCL Name", right_on="SA2 name", how="left")
# Identify mistmatched UCLs between the dataframes
missing_ucls_2018 = merged_df_2018[pd.isnull(merged_df_2018["SA2 name"])][merged_df_2018.columns]
# Display the 2018 merged data
merged_df_2018
# Out:
#                            UCL Name Final Dispatch Code %<=15mins  \
# 0   Albury - Wodonga (Wodonga Part)              Code 1    91.35%
# 1                     Bacchus Marsh              Code 1    79.85%
# 2                        Bairnsdale              Code 1    85.61%
# 3                          Ballarat              Code 1    89.32%
# 4                           Benalla              Code 1    84.08%
# ..                              ...                 ...       ...
# 74                           Wallan              Code 2       NaN
# 75                       Wangaratta              Code 2       NaN
# 76                         Warragul              Code 2       NaN
# 77                      Warrnambool              Code 2       NaN
# 78                Total UCLs > 7500              Code 2       NaN
#
#    AVG RT - Seconds Total Number       SA2 name  Total Persons
# 0               602         1735            NaN            NaN
# 1               693          784  Bacchus Marsh        22223.0
# 2               668          966     Bairnsdale        15411.0
# 3               627         5272       Ballarat        12175.0
# 4               682          534        Benalla        10436.0
# ..              ...          ...            ...            ...
# 74             1129          338         Wallan        18446.0
# 75             1475         1022     Wangaratta        19318.0
# 76             1514          890       Warragul        20149.0
# 77             1388         1248            NaN            NaN
# 78             1514       179712            NaN            NaN
#
# [79 rows x 7 columns]

# %%
# Merge 2019 dataframes
merged_df_2019 = pd.merge(ambulance_data_2019, census_data_2019_vic, left_on="UCL Name", right_on="SA2 name", how="left")
# Identify mistmatched UCLs between the dataframes
missing_ucls_2019 = merged_df_2019[pd.isnull(merged_df_2019["SA2 name"])][merged_df_2019.columns]
# Display the 2019 merged data
merged_df_2019
# Out:
#                                              UCL Name Final Dispatch Code  \
# 0                     Albury - Wodonga (Wodonga Part)              Code 1
# 1                                       Bacchus Marsh              Code 1
# 2                                          Bairnsdale              Code 1
# 3                                            Ballarat              Code 1
# 4                                             Benalla              Code 1
# ..                                                ...                 ...
# 86                                                NaN                 NaN
# 87                                                NaN                 NaN
# 88                                               NOTE                 NaN
# 89  1. The Maryborough (Vic.), Wonthaggi and Yarra...                 NaN
# 90  2. The Melbourne UCL was redefined by the Aust...                 NaN
#
#    %<=15mins AVG RT - Seconds Total Number       SA2 name  Total Persons
# 0      90.9%              604       2,050             NaN            NaN
# 1      83.4%              643         835   Bacchus Marsh        22964.0
# 2      84.1%              654       1,021      Bairnsdale        15565.0
# 3      91.2%              604       5,785        Ballarat        12225.0
# 4      76.4%              752         592         Benalla        10450.0
# ..       ...              ...          ...            ...            ...
# 86       NaN              NaN          NaN            NaN            NaN
# 87       NaN              NaN          NaN            NaN            NaN
# 88       NaN              NaN          NaN            NaN            NaN
# 89       NaN              NaN          NaN            NaN            NaN
# 90       NaN              NaN          NaN            NaN            NaN
#
# [91 rows x 7 columns]

# %%
# Display the 2018 missing UCL data
missing_ucls_2018
# Out:
#                             UCL Name  Final Dispatch Code %<=15mins  \
# 0    Albury - Wodonga (Wodonga Part)               Code 1    91.35%
# 9         Drysdale - Clifton Springs               Code 1    82.38%
# 10      Echuca - Moama (Echuca Part)               Code 1    86.65%
# 13                          Hamilton               Code 1    94.20%
# 14                       Healesville               Code 1    74.34%
# 20  Mildura - Buronga (Mildura Part)               Code 1    92.04%
# 24                          Pakenham               Code 1    81.43%
# 25                   Portland (Vic.)               Code 1    88.77%
# 27            Shepparton - Mooroopna               Code 1    91.34%
# 30                 Torquay - Jan Juc               Code 1    79.14%
# 35                       Warrnambool               Code 1    92.97%
# 36                 Total UCLs > 7500               Code 1    87.20%
# 37                               NaN                  NaN       NaN
# 38                               NaN                  NaN       NaN
# 39                               NaN                  NaN       NaN
# 40                               NaN                  NaN       NaN
# 41                          UCL Name  Final Dispatch Code       NaN
# 42   Albury - Wodonga (Wodonga Part)               Code 2       NaN
# 51        Drysdale - Clifton Springs               Code 2       NaN
# 52      Echuca - Moama (Echuca Part)               Code 2       NaN
# 55                          Hamilton               Code 2       NaN
# 56                       Healesville               Code 2       NaN
# 62  Mildura - Buronga (Mildura Part)               Code 2       NaN
# 66                          Pakenham               Code 2       NaN
# 67                   Portland (Vic.)               Code 2       NaN
# 69            Shepparton - Mooroopna               Code 2       NaN
# 72                 Torquay - Jan Juc               Code 2       NaN
# 77                       Warrnambool               Code 2       NaN
# 78                 Total UCLs > 7500               Code 2       NaN
#
#     AVG RT - Seconds  Total Number SA2 name  Total Persons
# 0                602          1735      NaN            NaN
# 9                707           505      NaN            NaN
# 10               657           854      NaN            NaN
# 13               543           379      NaN            NaN
# 14               722           565      NaN            NaN
# 20               558          2123      NaN            NaN
# 24               693          2213      NaN            NaN
# 25               596           561      NaN            NaN
# 27               593          2979      NaN            NaN
# 30               707           561      NaN            NaN
# 35               565          1480      NaN            NaN
# 36               640        236171      NaN            NaN
# 37               NaN           NaN      NaN            NaN
# 38               NaN           NaN      NaN            NaN
# 39               NaN           NaN      NaN            NaN
# 40               NaN           NaN      NaN            NaN
# 41  AVG RT - Seconds  Total Number      NaN            NaN
# 42              1325          1437      NaN            NaN
# 51              1257           394      NaN            NaN
# 52              1907           881      NaN            NaN
# 55              1501           414      NaN            NaN
# 56              1268           451      NaN            NaN
# 62              1553          1855      NaN            NaN
# 66              1338          1517      NaN            NaN
# 67              1432           572      NaN            NaN
# 69              1433          2438      NaN            NaN
# 72              1243           353      NaN            NaN
# 77              1388          1248      NaN            NaN
# 78              1514        179712      NaN            NaN

# %%
# Display the 2019 missing UCL data
missing_ucls_2019
# Out:
#                                              UCL Name  Final Dispatch Code  \
# 0                     Albury - Wodonga (Wodonga Part)               Code 1
# 9                          Drysdale - Clifton Springs               Code 1
# 10                       Echuca - Moama (Echuca Part)               Code 1
# 13                                           Hamilton               Code 1
# 14                                        Healesville               Code 1
# 18                              Maryborough (Vic) (1)              Code 1
# 19                                      Melbourne (2)               Code 1
# 21                   Mildura - Buronga (Mildura Part)               Code 1
# 25                                    Portland (Vic.)               Code 1
# 27                             Shepparton - Mooroopna               Code 1
# 30                                  Torquay - Jan Juc               Code 1
# 35                                        Warrnambool               Code 1
# 36                                      Wonthaggi (1)              Code 1
# 37         Yarrawonga - Mulwala (Yarrawonga Part) (1)               Code 1
# 38                                  Total UCLs > 7500               Code 1
# 39                                                NaN                  NaN
# 40                                               NOTE                  NaN
# 41  1. The Maryborough (Vic.), Wonthaggi and Yarra...                  NaN
# 42  2. The Melbourne UCL was redefined by the Aust...                  NaN
# 43                                                NaN                  NaN
# 44                                                NaN                  NaN
# 45                                                NaN                  NaN
# 46                                           UCL Name  Final Dispatch Code
# 47                    Albury - Wodonga (Wodonga Part)               Code 2
# 56                         Drysdale - Clifton Springs               Code 2
# 57                       Echuca - Moama (Echuca Part)               Code 2
# 60                                           Hamilton               Code 2
# 61                                        Healesville               Code 2
# 65                              Maryborough (Vic) (1)               Code 2
# 66                                      Melbourne (2)               Code 2
# 68                   Mildura - Buronga (Mildura Part)               Code 2
# 72                                    Portland (Vic.)               Code 2
# 74                             Shepparton - Mooroopna               Code 2
# 77                                  Torquay - Jan Juc               Code 2
# 82                                        Warrnambool               Code 2
# 83                                      Wonthaggi (1)              Code 2
# 84         Yarrawonga - Mulwala (Yarrawonga Part) (1)              Code 2
# 85                                  Total UCLs > 7500               Code 2
# 86                                                NaN                  NaN
# 87                                                NaN                  NaN
# 88                                               NOTE                  NaN
# 89  1. The Maryborough (Vic.), Wonthaggi and Yarra...                  NaN
# 90  2. The Melbourne UCL was redefined by the Aust...                  NaN
#
#    %<=15mins  AVG RT - Seconds  Total Number SA2 name  Total Persons
# 0      90.9%               604        2,050       NaN            NaN
# 9      84.7%               698          667       NaN            NaN
# 10     87.7%               606          826       NaN            NaN
# 13     92.3%               560          418       NaN            NaN
# 14     85.6%               610          555       NaN            NaN
# 18     82.0%               683          607       NaN            NaN
# 19     89.6%               608      192,915       NaN            NaN
# 21     94.6%               530        2,242       NaN            NaN
# 25     87.9%               606          539       NaN            NaN
# 27     91.6%               578        3,232       NaN            NaN
# 30     79.0%               731          686       NaN            NaN
# 35     93.5%               557        1,477       NaN            NaN
# 36     89.6%               590          626       NaN            NaN
# 37     74.6%               829          500       NaN            NaN
# 38     89.2%               611      250,386       NaN            NaN
# 39       NaN               NaN           NaN      NaN            NaN
# 40       NaN               NaN           NaN      NaN            NaN
# 41       NaN               NaN           NaN      NaN            NaN
# 42       NaN               NaN           NaN      NaN            NaN
# 43       NaN               NaN           NaN      NaN            NaN
# 44       NaN               NaN           NaN      NaN            NaN
# 45       NaN               NaN           NaN      NaN            NaN
# 46       NaN  AVG RT - Seconds  Total Number      NaN            NaN
# 47       NaN              1357        1,458       NaN            NaN
# 56       NaN              1198          467       NaN            NaN
# 57       NaN              1890          937       NaN            NaN
# 60       NaN              1370          431       NaN            NaN
# 61       NaN               983          417       NaN            NaN
# 65       NaN              1542          732       NaN            NaN
# 66       NaN              1400      139,760       NaN            NaN
# 68       NaN              1551        1,811       NaN            NaN
# 72       NaN              1552          556       NaN            NaN
# 74       NaN              1324        2,529       NaN            NaN
# 77       NaN              1212          465       NaN            NaN
# 82       NaN              1254        1,295       NaN            NaN
# 83       NaN              1804          691       NaN            NaN
# 84       NaN              1476          485       NaN            NaN
# 85       NaN              1392      184,894       NaN            NaN
# 86       NaN               NaN           NaN      NaN            NaN
# 87       NaN               NaN           NaN      NaN            NaN
# 88       NaN               NaN           NaN      NaN            NaN
# 89       NaN               NaN           NaN      NaN            NaN
# 90       NaN               NaN           NaN      NaN            NaN

# %%
# Identify mistmatched UCLs between the dataframes and clean the data to display only code 1 for 2018
merged_df_clean_2018 = merged_df_2018[~pd.isnull(merged_df_2018["SA2 name"])][merged_df_2018.columns]
merged_df_sorted_2018 = merged_df_clean_2018.sort_values("Total Persons",ascending=False)
merged_df_sorted_2018 = merged_df_sorted_2018[merged_df_sorted_2018["Final Dispatch Code"] == "Code 1"]
merged_df_sorted_2018["AVG RT - Seconds"] = merged_df_sorted_2018["AVG RT - Seconds"].astype(int)
# Display the 2018 sorted data
merged_df_sorted_2018
# Out:
#                       UCL Name Final Dispatch Code %<=15mins  \
# 18                   Melbourne              Code 1    87.29%
# 31                   Traralgon              Code 1    82.01%
# 23  Ocean Grove - Barwon Heads              Code 1    84.17%
# 1                Bacchus Marsh              Code 1    79.85%
# 19                      Melton              Code 1    81.37%
# 34                    Warragul              Code 1    83.45%
# 16                        Lara              Code 1    85.98%
# 33                  Wangaratta              Code 1    90.80%
# 32                      Wallan              Code 1    89.84%
# 8                       Drouin              Code 1    75.00%
# 21            Moe - Newborough              Code 1    80.03%
# 15                     Horsham              Code 1    92.41%
# 2                   Bairnsdale              Code 1    85.61%
# 26                        Sale              Code 1    89.71%
# 5                      Bendigo              Code 1    86.25%
# 22                     Morwell              Code 1    89.30%
# 12                    Gisborne              Code 1    74.27%
# 17                     Leopold              Code 1    90.00%
# 11                     Geelong              Code 1    89.37%
# 28                     Sunbury              Code 1    81.18%
# 7                        Colac              Code 1    85.37%
# 3                     Ballarat              Code 1    89.32%
# 29                   Swan Hill              Code 1    89.88%
# 6                  Castlemaine              Code 1    71.43%
# 4                      Benalla              Code 1    84.08%
#
#     AVG RT - Seconds Total Number                    SA2 name  Total Persons
# 18               640       182520                   Melbourne        49097.0
# 31               686         1562                   Traralgon        27958.0
# 23               676          638  Ocean Grove - Barwon Heads        26648.0
# 1                693          784               Bacchus Marsh        22223.0
# 19               667         3436                      Melton        20188.0
# 34               685          864                    Warragul        20149.0
# 16               646          535                        Lara        19978.0
# 33               596         1109                  Wangaratta        19318.0
# 32               600          433                      Wallan        18446.0
# 8                792          624                      Drouin        17779.0
# 21               677         1532            Moe - Newborough        16812.0
# 15               553          936                     Horsham        16514.0
# 2                668          966                  Bairnsdale        15411.0
# 26               570          622                        Sale        15021.0
# 5                659         5098                     Bendigo        14735.0
# 22               589         1598                     Morwell        14026.0
# 12               738          412                    Gisborne        13963.0
# 17               597          450                     Leopold        13753.0
# 11               631         9030                     Geelong        13498.0
# 28               666         1769                     Sunbury        13397.0
# 7                680          547                       Colac        12547.0
# 3                627         5272                    Ballarat        12175.0
# 29               566          504                   Swan Hill        11103.0
# 6                890          441                 Castlemaine        11047.0
# 4                682          534                     Benalla        10436.0

# %%
# Identify mistmatched UCLs between the dataframes and clean the data to display only code 1 for 2019
merged_df_clean_2019 = merged_df_2019[~pd.isnull(merged_df_2019["SA2 name"])][merged_df_2019.columns]
merged_df_sorted_2019 = merged_df_clean_2019.sort_values("Total Persons",ascending=False)
merged_df_sorted_2019 = merged_df_sorted_2019[merged_df_sorted_2019["Final Dispatch Code"] == "Code 1"]
merged_df_sorted_2019["AVG RT - Seconds"] = merged_df_sorted_2019["AVG RT - Seconds"].astype(int)
# Display the 2019 sorted data
merged_df_sorted_2019
# Out:
#                       UCL Name Final Dispatch Code %<=15mins  \
# 31                   Traralgon              Code 1     84.2%
# 24  Ocean Grove - Barwon Heads              Code 1     84.9%
# 1                Bacchus Marsh              Code 1     83.4%
# 34                    Warragul              Code 1     83.0%
# 20                      Melton              Code 1     86.3%
# 16                        Lara              Code 1     84.4%
# 32                      Wallan              Code 1     86.0%
# 33                  Wangaratta              Code 1     90.7%
# 8                       Drouin              Code 1     84.9%
# 22            Moe - Newborough              Code 1     83.9%
# 15                     Horsham              Code 1     92.6%
# 2                   Bairnsdale              Code 1     84.1%
# 26                        Sale              Code 1     89.1%
# 5                      Bendigo              Code 1     87.4%
# 12                    Gisborne              Code 1     74.4%
# 23                     Morwell              Code 1     92.5%
# 17                     Leopold              Code 1     87.9%
# 11                     Geelong              Code 1     88.4%
# 28                     Sunbury              Code 1     87.8%
# 7                        Colac              Code 1     86.2%
# 3                     Ballarat              Code 1     91.2%
# 6                  Castlemaine              Code 1     73.0%
# 29                   Swan Hill              Code 1     90.0%
# 4                      Benalla              Code 1     76.4%
#
#     AVG RT - Seconds Total Number                    SA2 name  Total Persons
# 31               667       1,611                    Traralgon        28207.0
# 24               640         780   Ocean Grove - Barwon Heads        28053.0
# 1                643         835                Bacchus Marsh        22964.0
# 34               659         816                     Warragul        20764.0
# 20               602       3,727                       Melton        20596.0
# 16               667         636                         Lara        20579.0
# 32               608         457                       Wallan        19654.0
# 33               597       1,164                   Wangaratta        19411.0
# 8                702         656                       Drouin        18453.0
# 22               614       1,757             Moe - Newborough        16821.0
# 15               551         952                      Horsham        16589.0
# 2                654       1,021                   Bairnsdale        15565.0
# 26               568         717                         Sale        15135.0
# 5                645       5,567                      Bendigo        14779.0
# 12               694         449                     Gisborne        14211.0
# 23               563       1,610                      Morwell        14042.0
# 17               610         513                      Leopold        13836.0
# 11               633       9,982                      Geelong        13587.0
# 28               606       1,721                      Sunbury        13558.0
# 7                653         607                        Colac        12574.0
# 3                604       5,785                     Ballarat        12225.0
# 6                812         482                  Castlemaine        11196.0
# 29               571         609                    Swan Hill        11089.0
# 4                752         592                      Benalla        10450.0

# %%
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(merged_df_sorted_2018["Total Persons"], merged_df_sorted_2018["AVG RT - Seconds"])
regress_values = merged_df_sorted_2018["Total Persons"] * slope + intercept
plt.plot(merged_df_sorted_2018["Total Persons"],regress_values, color="r")
plt.scatter(merged_df_sorted_2018["Total Persons"],merged_df_sorted_2018["AVG RT - Seconds"])
(slope2, intercept2, rvalue2, pvalue2, stderr2) = st.linregress(merged_df_sorted_2019["Total Persons"], merged_df_sorted_2019["AVG RT - Seconds"])
regress_values2 = merged_df_sorted_2019["Total Persons"] * slope2 + intercept2
plt.plot(merged_df_sorted_2019["Total Persons"],regress_values2, color="b")
plt.scatter(merged_df_sorted_2019["Total Persons"],merged_df_sorted_2019["AVG RT - Seconds"])
plt.xlabel("Total Persons")
plt.ylabel("AVG RT - Seconds")
plt.show()
